# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/boston-housing/BostonHousing.csv')

# %%
df.shape
# Out:
# (506, 14)

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# b       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio         b     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# b        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
import matplotlib.pyplot as plt 
plt.hist(df["medv"])
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
from mlxtend.plotting import scatterplotmatrix 
cols = ['crim', 'zn', 'indus', 'chas', "medv"]
scatterplotmatrix(df[cols].values, figsize=(10,8), names=cols,alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from mlxtend.plotting import heatmap
cm = np.corrcoef(df[cols].values.T)
hm = heatmap(cm, row_names=cols, column_names=cols)
plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=999)

# %%
from  sklearn.linear_model import ElasticNet 
enet = ElasticNet(alpha=1.0, l1_ratio=0.5)

# %%
enet.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
y_pred = enet.predict(X_test)

# %%
y_pred
# Out:
# array([23.04930116, 23.96493313, 26.87155865, 11.10081304, 25.14267113,
#        25.36705788, 20.4494572 , 23.3439132 , 22.50731902, 33.64903718,
#        18.46759312, 23.1037994 , 31.77833278, 29.80734168, 18.14603195,
#        12.86720868, 23.85543046, 18.83212388, 16.16032576, 27.85146159,
#        20.05613973, 28.20091845, 23.62343156, 14.96904318, 15.92259531,
#        31.44956897, 24.72718682, 22.5717637 , 26.99660439, 31.56787238,
#        31.58752673, 24.38249487, 15.31655978, 21.04150505, 15.80513337,
#        19.53730121, 23.77323528, 21.02331423, -0.58310253, 27.58502138,
#        27.91349095, 12.3104392 , 24.73608296, 16.3650161 , 27.74090623,
#        29.70058904, 13.98100716, 20.63796789, 21.74917303, 27.82959767,
#        23.16976517, 30.01837411, 25.0483095 , 14.00505199, 24.14765385,
#         9.01500978, 30.30821903, 21.47702332, 23.43165238, 27.50643732,
#        27.74353496, 24.91272409, 16.60147067, 14.45059299, 25.15581967,
#        24.84489834, 20.21229473, 23.20912614, 28.17884587, 28.99527848,
#        14.80339256, 12.31245875, 17.90341638, 22.18161423, 28.50204891,
#        17.88181088, 29.90395474, 22.30810815, 30.47745861, 28.71780774,
#        37.81092977, 32.16073091, 33.7713439 , 22.37469395, 31.90164853,
#        19.0919642 , 25.72595829, 26.8967889 , 21.55984896, 26.1373431 ,
#        20.43651118, 18.84092266, 27.56391049, 34.73043667, 19.11369905,
#        35.41831928, 32.99724601, 35.83000382, 19.91482069, 20.97760791,
#        19.50232358, 22.46720157, 34.38932791, 19.02261031, 33.6139578 ,
#        23.03249993, 16.91880729, 15.27919   , 17.91930928, -4.26994934,
#         3.51460428, 23.74682106, 20.71882301, 30.45744773, 24.71023812,
#        31.16055658, 21.5503086 , 27.92238903, 23.21823639, 34.60053214,
#        21.28673506, 11.4957242 , 32.48370793, 17.26134652,  5.99432555,
#        19.01944922, 19.72179927])

# %%
print("Slope: %.2f" % enet.coef_[0])
# Out:
# Slope: -0.10

# %%
print("Intercept: %.2f" % enet.intercept_)
# Out:
# Intercept: 43.93

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 28.48394537370573
